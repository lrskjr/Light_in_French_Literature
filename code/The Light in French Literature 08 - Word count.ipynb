# %%
import os
import pandas as pd
from pathlib import Path
import textdistance
import re

from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# # Get data

# %%
input_dir = Path.cwd() / '../data/csv_files' # input directory
df = pd.read_csv(input_dir /'text_data28_09_24.csv', sep='|')

# %%
df
# Out:
#     year  author                                              title  \
# 0   1838  Balzac  Splendeurs et miseres des courtisanes 1 Esther...
# 1   1838  Balzac  Splendeurs et miseres des courtisanes 2 A comb...
# 2   1838  Balzac  Splendeurs et miseres des courtisanes 3 Ou men...
# 3   1838  Balzac  Splendeurs et miseres des courtisanes 4 La der...
# 4   1842  Balzac                                    La Rabouilleuse
# ..   ...     ...                                                ...
# 85  1924  Proust                                 Sodome et Gomorrhe
# 86  1925    Gide                                Les Faux monnayeurs
# 87  1925  Leroux                                 La Reine du Sabbat
# 88  1925  Proust                                 Albertine disparue
# 89  1927  Proust                                  Le Temps retrouve
#
#                                                  text  \
# 0   SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# ...

# %% [markdown]
# # Word count

# %%
text = ' '.join(df['clean_text'])

print (f'Allumette-bougie is {text.count("allumette-bougie")} times in the corpus.')

print (f'Bougie is {text.count("bougie")} times in the corpus.')
# Out:
# Allumette-bougie is 2 times in the corpus.
# Bougie is 471 times in the corpus.
